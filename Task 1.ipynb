# %% [markdown]
# # Importing data and summerizing it

# %%
import pandas as pd
# importing pandas as pd for reading

# %%
data=pd.read_csv("iris.data",names=["Sepal_Length(in cm)","Sepal_Width(in cm)","Petal_Length(in cm)","Petal_Width(in cm)","Class"])
# reading data using pandas.read_csv and adding header using names as parameter for column.

# %%
df=pd.DataFrame(data)
df
# Showing the data
# Out:
#      Sepal_Length(in cm)  Sepal_Width(in cm)  Petal_Length(in cm)  \
# 0                    5.1                 3.5                  1.4
# 1                    4.9                 3.0                  1.4
# 2                    4.7                 3.2                  1.3
# 3                    4.6                 3.1                  1.5
# 4                    5.0                 3.6                  1.4
# ..                   ...                 ...                  ...
# 145                  6.7                 3.0                  5.2
# 146                  6.3                 2.5                  5.0
# 147                  6.5                 3.0                  5.2
# 148                  6.2                 3.4                  5.4
# 149                  5.9                 3.0                  5.1
#
#      Petal_Width(in cm)           Class
# 0                   0.2     Iris-setosa
# 1                   0.2     Iris-setosa
# 2                   0.2     Iris-setosa
# ...

# %%
df["Class"].unique()
# Three types of Classes
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.groupby(["Class"]).count()
# Each Class has 50 Values
# Out:
#                  Sepal_Length(in cm)  Sepal_Width(in cm)  Petal_Length(in cm)  \
# Class
# Iris-setosa                       50                  50                   50
# Iris-versicolor                   50                  50                   50
# Iris-virginica                    50                  50                   50
#
#                  Petal_Width(in cm)
# Class
# Iris-setosa                      50
# Iris-versicolor                  50
# Iris-virginica                   50

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        Sepal_Length(in cm)  Sepal_Width(in cm)  Petal_Length(in cm)  \
# count           150.000000          150.000000           150.000000
# mean              5.843333            3.054000             3.758667
# std               0.828066            0.433594             1.764420
# min               4.300000            2.000000             1.000000
# 25%               5.100000            2.800000             1.600000
# 50%               5.800000            3.000000             4.350000
# 75%               6.400000            3.300000             5.100000
# max               7.900000            4.400000             6.900000
#
#        Petal_Width(in cm)
# count          150.000000
# mean             1.198667
# std              0.763161
# min              0.100000
# 25%              0.300000
# 50%              1.300000
# 75%              1.800000
# max              2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sepal_Length(in cm)  150 non-null    float64
#  1   Sepal_Width(in cm)   150 non-null    float64
#  2   Petal_Length(in cm)  150 non-null    float64
#  3   Petal_Width(in cm)   150 non-null    float64
#  4   Class                150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Data Visualisation

# %%
# Pie Chart

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6))
clrs = ['pink','lightblue','lightgreen']
classes = df['Class'].unique()
counts = df['Class'].value_counts()
plt.pie(counts, labels = classes, autopct='%1.3f%%', colors=clrs, startangle=90)
plt.show()

# %%
# Pairplotting of Attibutes

import seaborn as sns
sns.pairplot(df,hue='Class',palette='cool')
plt.show()

# %%
# Histogram visualistion of attributes
from matplotlib import style

plt.figure(figsize=(13,10))

plt.subplot(2,2,1)
plt.title('Sepal_Length(in cm)')
plt.hist(df['Sepal_Length(in cm)'],bins=8,edgecolor='black',color='lightblue')

plt.subplot(2,2,2)
plt.title('Sepal_Width(in cm)')
plt.hist(df['Sepal_Width(in cm)'],bins=5,edgecolor='black',color='lightgreen')

plt.subplot(2,2,3)
plt.title('Petal_Length(in cm)')
plt.hist(df['Petal_Length(in cm)'],bins=7,edgecolor='black',color='yellow')

plt.subplot(2,2,4)
plt.title('Petal_Width(in cm)')
plt.hist(df['Petal_Width(in cm)'],bins=3,edgecolor='black',color='pink')

plt.show()

# %%
# Scatter Plot Visualisation for Petal Length vs Petal Width

setosa = df[df['Class'] == "Iris-setosa"]
virginica = df[df['Class'] == "Iris-virginica"]
versicolor = df[df['Class'] == "Iris-versicolor"]
plt.figure(figsize=(7,7))
plt.scatter(setosa['Sepal_Length(in cm)'], setosa['Sepal_Width(in cm)'], c="darkblue", label="Setosa")
plt.scatter(versicolor['Sepal_Length(in cm)'],versicolor['Sepal_Width(in cm)'], c="red", label="Versicolor")
plt.scatter(virginica['Sepal_Length(in cm)'],virginica['Sepal_Width(in cm)'], c="darkgreen", label="Virginica")
plt.xlabel("Sepal_Length(in cm)")
plt.ylabel("Sepal_Width(in cm)")
plt.title("Sepal_Length(in cm) vs Sepal_Width(in cm)\n", fontsize=20)
plt.legend()
plt.show()

# %%
# Scatter Plot Visualisation for Sepal Length vs Sepal Width

plt.figure(figsize=(7,7))
plt.scatter(setosa['Petal_Length(in cm)'], setosa['Petal_Width(in cm)'], c="darkblue", label="Setosa")
plt.scatter(versicolor['Petal_Length(in cm)'],versicolor['Petal_Width(in cm)'], c="red", label="Versicolor")
plt.scatter(virginica['Petal_Length(in cm)'],virginica['Petal_Width(in cm)'], c="darkgreen", label="Virginica")
plt.xlabel("Petal_Length(in cm)")
plt.ylabel("Petal_Width(in cm)")
plt.title("Petal_Length(in cm) vs Petal_Width(in cm)\n", fontsize=20)
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from warnings import filterwarnings
filterwarnings('ignore')

X = df.drop(['Class'],1)
y = df['Class']
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
nb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %%
models = [lr, knn, svm, nb, dt, rf]
scores = []
for model in models:
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  scores.append(accuracy_score(y_test, y_pred))
  print("Accuracy of " + type(model).__name__ + " is", accuracy_score(y_test, y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9777777777777777
# Accuracy of KNeighborsClassifier is 0.9777777777777777
# Accuracy of SVC is 0.9777777777777777
# Accuracy of GaussianNB is 0.9333333333333333
# Accuracy of DecisionTreeClassifier is 0.9555555555555556
# Accuracy of RandomForestClassifier is 0.9555555555555556

# %%
results = pd.DataFrame({
    'Models': ['Logistic Regression', 'K-Nearest Neighbors', 'Support Vector Machine', 'Naive Bayes', 'Decision Tree', 'Random Forest'],
    'Accuracy': scores})

results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                    Models  Accuracy
# 0     Logistic Regression  0.977778
# 1     K-Nearest Neighbors  0.977778
# 2  Support Vector Machine  0.977778
# 4           Decision Tree  0.955556
# 5           Random Forest  0.955556
# 3             Naive Bayes  0.933333
